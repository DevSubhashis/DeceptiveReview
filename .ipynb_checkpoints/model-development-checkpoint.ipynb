# %%
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import TfidfVectorizer

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

# %%
# Evaluation Metrics
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/processed_reviews.csv")

# %%
print(df.head())
# Out:
#                                              college  \
# 0                sns college of technology - [snsct]
# 1           bhagalpur college of engineering - [bce]
# 2  shree lr tiwari college of engineering - [slrtce]
# 3                                    iilm university
# 4                        galgotias university - [gu]
#
#                                               review  rating  label  \
# 0  the annual fee for the course is 1,25,000. now...     6.0      0
# 1  the hostel life and social life in this colleg...     9.7      0
# 2  i chose this course because i was interested i...     8.0      0
# 3  there is ignite fest in the university held on...    10.0      0
# 4  the civil department is very good in this coll...     6.2      0
#
#                                     processed_review
# 0  annual fee course force pay fee early total bo...
# 1  hostel life social life college enjoyable club...
# 2  choose course interested mechanical engineerin...
# 3  ignite f university hold campus availability j...
# 4  civil department good college faculty member g...

# %%
print(df.shape)
# Out:
# (40003, 5)

# %%
X = df["processed_review"]

# %%
y = df["label"]

# %%
tfidf = TfidfVectorizer(
    
    max_features=5000,
    
    ngram_range=(1,2),
    
    max_df=0.95,
    
    min_df=2
)

X_tfidf = tfidf.fit_transform(X)

print("\nTF-IDF Shape:")
print(X_tfidf.shape)
# Out:
# TF-IDF Shape:
# (40003, 5000)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    
    X_tfidf,
    y,
    
    test_size=0.2,
    
    random_state=42,
    
    stratify=y
)

print("\nTraining Shape:")
print(X_train.shape)

print("\nTesting Shape:")
print(X_test.shape)
# Out:
# Training Shape:
# (32002, 5000)
#
# Testing Shape:
# (8001, 5000)

# %%
print("\n=================================================")
print("LOGISTIC REGRESSION")
print("=================================================")

lr_model = LogisticRegression(
    
    max_iter=1000
)

# Train model
lr_model.fit(X_train, y_train)

# Prediction
y_pred_lr = lr_model.predict(X_test)
# Out:
# =================================================
# LOGISTIC REGRESSION
# =================================================

# %%
# ---------------------------------------------------------
# EVALUATION
# ---------------------------------------------------------

lr_accuracy = accuracy_score(y_test, y_pred_lr)

lr_precision = precision_score(y_test, y_pred_lr)

lr_recall = recall_score(y_test, y_pred_lr)

lr_f1 = f1_score(y_test, y_pred_lr)

print("\nAccuracy:", lr_accuracy)

print("Precision:", lr_precision)

print("Recall:", lr_recall)

print("F1 Score:", lr_f1)

# Classification Report
print("\nClassification Report:\n")

print(classification_report(y_test, y_pred_lr))
# Out:
# Accuracy: 0.8660167479065117
# Precision: 0.9359895493141738
# Recall: 0.5953469048608226
# F1 Score: 0.7277805992889792
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      5594
#            1       0.94      0.60      0.73      2407
#
#     accuracy                           0.87      8001
#    macro avg       0.89      0.79      0.82      8001
# weighted avg       0.88      0.87      0.86      8001

# %%
# CONFUSION MATRIX

# %%
cm_lr = confusion_matrix(y_test, y_pred_lr)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm_lr,
    
    annot=True,
    
    fmt='d',
    
    cmap='Blues'
)

plt.title("Logistic Regression Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()

# %%
print("\n=================================================")
print("NAIVE BAYES")
print("=================================================")

nb_model = MultinomialNB()

# Train model
nb_model.fit(X_train, y_train)

# Prediction
y_pred_nb = nb_model.predict(X_test)
# Out:
# =================================================
# NAIVE BAYES
# =================================================

# %%
# ---------------------------------------------------------
# EVALUATION
# ---------------------------------------------------------

nb_accuracy = accuracy_score(y_test, y_pred_nb)

nb_precision = precision_score(y_test, y_pred_nb)

nb_recall = recall_score(y_test, y_pred_nb)

nb_f1 = f1_score(y_test, y_pred_nb)

print("\nAccuracy:", nb_accuracy)

print("Precision:", nb_precision)

print("Recall:", nb_recall)

print("F1 Score:", nb_f1)

# Classification Report
print("\nClassification Report:\n")

print(classification_report(y_test, y_pred_nb))
# Out:
# Accuracy: 0.8147731533558306
# Precision: 0.9904559915164369
# Recall: 0.3880348982135438
# F1 Score: 0.5576119402985075
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      5594
#            1       0.99      0.39      0.56      2407
#
#     accuracy                           0.81      8001
#    macro avg       0.89      0.69      0.72      8001
# weighted avg       0.85      0.81      0.79      8001

# %%
# CONFUSION MATRIX

# %%
cm_nb = confusion_matrix(y_test, y_pred_nb)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm_nb,
    
    annot=True,
    
    fmt='d',
    
    cmap='Greens'
)

plt.title("Naive Bayes Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()

# %%
print("\n=================================================")
print("RANDOM FOREST")
print("=================================================")

rf_model = RandomForestClassifier(
    
    n_estimators=100,
    
    random_state=42
)

# Train model
rf_model.fit(X_train, y_train)

# Prediction
y_pred_rf = rf_model.predict(X_test)
# Out:
# =================================================
# RANDOM FOREST
# =================================================

# %%
# ---------------------------------------------------------
# EVALUATION
# ---------------------------------------------------------

rf_accuracy = accuracy_score(y_test, y_pred_rf)

rf_precision = precision_score(y_test, y_pred_rf)

rf_recall = recall_score(y_test, y_pred_rf)

rf_f1 = f1_score(y_test, y_pred_rf)

print("\nAccuracy:", rf_accuracy)

print("Precision:", rf_precision)

print("Recall:", rf_recall)

print("F1 Score:", rf_f1)

# Classification Report
print("\nClassification Report:\n")

print(classification_report(y_test, y_pred_rf))
# Out:
# Accuracy: 0.8785151856017998
# Precision: 0.9111747851002865
# Recall: 0.6605733277939344
# F1 Score: 0.7658959537572254
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      5594
#            1       0.91      0.66      0.77      2407
#
#     accuracy                           0.88      8001
#    macro avg       0.89      0.82      0.84      8001
# weighted avg       0.88      0.88      0.87      8001

# %%
# CONFUSION MATRIX

# %%
cm_rf = confusion_matrix(y_test, y_pred_rf)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm_rf,
    
    annot=True,
    
    fmt='d',
    
    cmap='Oranges'
)

plt.title("Random Forest Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()

# %%
# MODEL COMPARISON

# %%
results = pd.DataFrame({

    "Model": [
        "Logistic Regression",
        "Naive Bayes",
        "Random Forest"
    ],
    
    "Accuracy": [
        lr_accuracy,
        nb_accuracy,
        rf_accuracy
    ],
    
    "Precision": [
        lr_precision,
        nb_precision,
        rf_precision
    ],
    
    "Recall": [
        lr_recall,
        nb_recall,
        rf_recall
    ],
    
    "F1 Score": [
        lr_f1,
        nb_f1,
        rf_f1
    ]
})

print("\n=================================================")
print("MODEL COMPARISON")
print("=================================================")

results
# Out:
# =================================================
# MODEL COMPARISON
# =================================================
#                  Model  Accuracy  Precision    Recall  F1 Score
# 0  Logistic Regression  0.866017   0.935990  0.595347  0.727781
# 1          Naive Bayes  0.814773   0.990456  0.388035  0.557612
# 2        Random Forest  0.878515   0.911175  0.660573  0.765896

# %%
# ---------------------------------------------------------
# VISUALIZE MODEL COMPARISON
# ---------------------------------------------------------

plt.figure(figsize=(10,6))

sns.barplot(
    
    x="Model",
    
    y="Accuracy",
    
    data=results
)

plt.title("Model Accuracy Comparison")

plt.ylim(0,1)

plt.show()

# %%
# =========================================================
# SAVE BEST MODEL
# =========================================================


pickle.dump(
    rf_model,
    
    open("model/rf_model_model.pkl", "wb")
)

print("\nLogistic Regression Model Saved Successfully!")

# Save TF-IDF vectorizer

pickle.dump(
    tfidf,
    
    open("model/tfidf_vectorizer.pkl", "wb")
)

print("TF-IDF Vectorizer Saved Successfully!")
# Out:
# Logistic Regression Model Saved Successfully!
# TF-IDF Vectorizer Saved Successfully!

# %%
# =========================================================
# SAMPLE PREDICTION
# =========================================================

sample_review = [
    "best college excellent placement amazing faculty"
]

sample_vector = tfidf.transform(sample_review)

prediction = lr_model.predict(sample_vector)

print("\nSample Review Prediction:")

if prediction[0] == 1:
    
    print("Fake Review")
    
else:
    
    print("Genuine Review")
# Out:
# Sample Review Prediction:
# Fake Review

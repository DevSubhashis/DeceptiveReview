# %%
# Import Liabrary 
import pandas as pd
import re
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# Load the CSV files
df1 = pd.read_csv("data/collegereview2021.csv")
df2 = pd.read_csv("data/collegereview2022.csv")

# %%
# concat the data
df = pd.concat([df1, df2], ignore_index=True)
df.head()
# Out:
#   Unnamed: 0               Name  \
# 0          0           Nimalraj
# 1          1  Priyaranjan kumar
# 2          2       Aftab Shaikh
# 3          3        Shreya sneh
# 4          4      Yuv Raj Singh
#
#                                              college  \
# 0                SNS College of Technology - [SNSCT]
# 1           Bhagalpur College of Engineering - [BCE]
# 2  Shree LR Tiwari College of Engineering - [SLRTCE]
# 3                                    IILM University
# 4                        Galgotias University - [GU]
#
#                                               review  rating
# 0  The annual fee for the course is 1,25,000. Now...     6.0
# 1  The hostel life and social life in this colleg...     9.7
# 2  I chose this course because I was interested i...     8.0
# 3  There is IGNITE fest in the university held on...    10.0
# 4  The civil department is very good in this coll...     6.2

# %%
# Shape
df.shape
# Out:
# (28076, 5)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'college', 'review', 'rating'], dtype='object')

# %%
# Delete unnecessary columns
# 'Unnamed: 0' and 'Name' will not help model. so removing it
df = df.drop(["Unnamed: 0", "Name"], axis=1)

# %%
df.head()
# Out:
#                                              college  \
# 0                SNS College of Technology - [SNSCT]
# 1           Bhagalpur College of Engineering - [BCE]
# 2  Shree LR Tiwari College of Engineering - [SLRTCE]
# 3                                    IILM University
# 4                        Galgotias University - [GU]
#
#                                               review  rating
# 0  The annual fee for the course is 1,25,000. Now...     6.0
# 1  The hostel life and social life in this colleg...     9.7
# 2  I chose this course because I was interested i...     8.0
# 3  There is IGNITE fest in the university held on...    10.0
# 4  The civil department is very good in this coll...     6.2

# %%
# making college name lowercase
df["college"] = df["college"].str.strip().str.lower()

# %%
df.sample(5)
# Out:
#                                                  college  \
# 679               government engineering college - [gec]
# 17551    netaji subhas university of technology - [nsut]
# 19653  harcourt butler technological university - [hbtu]
# 6252              government engineering college wayanad
# 2400   harcourt butler technological university - [hbtu]
#
#                                                   review  rating
# 679    The course curriculum is good & well-experienc...     9.0
# 17551  College life is pretty decent in NSUT if we pu...     7.2
# 19653  Here the fest is good you know we had Yasser D...     7.5
# 6252   Annual sports fest and all. There are almost t...     5.2
# 2400   The campus of Harcourt butter technical Univer...     7.8

# %%
# making review lowercase
df["review"] = df["review"].str.strip().str.lower()

# %%
df.sample(5)
# Out:
#                                                  college  \
# 14470               vaagdevi engineering college - [vec]
# 6874                                        nit warangal
# 1544                       atria institute of technology
# 2160    kamala institute of technology & science- [kits]
# 3495   aurora's technological and research institute ...
#
#                                                   review  rating
# 14470  the college fee 48000 per year. we get a reimb...    10.0
# 6874   springspree is one of the prestigious fests wh...     7.4
# 1544   sptharang is the annual fest it is conducted i...     8.2
# 2160   the infrastructure in the college is too good....     9.4
# 3495   wipro, tata, amazon, tcl, and more companies c...     8.8

# %%
# DATA CLEANING

# %%
print("Rating is NaN:", df["rating"].isna().sum())
print("Empty reviews:", (df["review"].isna() | (df["review"].str.strip() == "")).sum())
df.shape
# Out:
# Rating is NaN: 105
# Empty reviews: 81
# (28076, 3)

# %%
# we have a lerge dataset , can remove rows with raing NAN
df = df.dropna(subset=["rating"])

# %%
# we have a lerge dataset , can remove empty and nan reviews
df = df[~(df["review"].isna() | (df["review"].str.strip() == ""))]

# %%
print("Rating is NaN:", df["rating"].isna().sum())
print("Empty reviews:", (df["review"].isna() | (df["review"].str.strip() == "")).sum())
df.shape
# Out:
# Rating is NaN: 0
# Empty reviews: 0
# (27971, 3)

# %%
# FEARURE ENGINEERING

# %%
# Dataset do't have label

# %%
# Apply labeling
df["label"] = 0

# %%
df.head()
# Label = 1 → Fake
# Label = 0 → Genuine
# Out:
#                                              college  \
# 0                sns college of technology - [snsct]
# 1           bhagalpur college of engineering - [bce]
# 2  shree lr tiwari college of engineering - [slrtce]
# 3                                    iilm university
# 4                        galgotias university - [gu]
#
#                                               review  rating  label
# 0  the annual fee for the course is 1,25,000. now...     6.0      0
# 1  the hostel life and social life in this colleg...     9.7      0
# 2  i chose this course because i was interested i...     8.0      0
# 3  there is ignite fest in the university held on...    10.0      0
# 4  the civil department is very good in this coll...     6.2      0

# %%
df = df.reset_index(drop=True)

# %%
print("Label = 0:", (df["label"] == 0).sum())
print("Label = 1:", (df["label"] == 1).sum())
# Out:
# Label = 0: 27971
# Label = 1: 0

# %%
df["label"].value_counts()
# Out:
# label
# 0    27971
# Name: count, dtype: int64

# %%
# I augmented the dataset by generating synthetic deceptive 
# reviews based on common linguistic patterns observed in fake reviews.

# %%
df3 = pd.read_csv("data/fake_reviews.csv")

# %%
df3.head()
# Out:
#              Name                                    college  \
# 0     Muskan arya      Birla Institute of Technology - [BIT]
# 1      Raju Bayya  Guru Nanak Dev University Regional Campus
# 2  Shashi jaiswal           Kuriakose Elias College Mannanam
# 3    Piyush Madan            Manav Rachna University - [MRU]
# 4             jay        Vishwakarma Institute of Technology
#
#                                               review  rating  label
# 0  The college has decent faculty support, althou...       3      1
# 1  Hostel facilities are manageable, but food qua...       4      1
# 2  The college has decent faculty support, althou...       5      1
# 3  Placement records shown during admission look ...       4      1
# 4  The faculty members are supportive, but placem...       5      1

# %%
# Delete Name Column
df3 = df3.drop(["Name"], axis=1)

# %%
df = pd.concat([df, df3], ignore_index=True)

# %%
df.sample(5)
# Out:
#                                                  college  \
# 2656   noida institute of engineering and technology ...
# 36718              Institute of Hotel Management - [IHM]
# 13913  jawaharlal nehru technological university - [j...
# 23294  srm institute of science and technology - [srm...
# 26983  j.b. institute of engineering & technology - [...
#
#                                                   review  rating  label
# 2656   in counseling, i choose computer science and e...     7.6      0
# 36718  Campus infrastructure is good, although manage...     3.0      1
# 13913  i choose this course because of my interest an...     7.6      0
# 23294  first of all, the campus is really huge and is...     8.0      0
# 26983  course curriculum is very helpful each and eve...     7.2      0

# %%
print("Label = 0:", (df["label"] == 0).sum())
print("Label = 1:", (df["label"] == 1).sum())
df.shape
# Out:
# Label = 0: 27971
# Label = 1: 12032
# (40003, 4)

# %%
df.to_csv("data/labeled_reviews.csv", index=True)

# %%
# DATA PRE-PROCESSING

# %%
# We have spacy
# This function performs: Tokenization, Stopword removal, Punctuation removal, Lemmatization

def preprocess_text(text):
    doc = nlp(str(text).lower())
    
    tokens = []
    
    for token in doc:
        # remove stopwords, punctuation, spaces
        if token.is_stop:
            continue
        
        if token.is_punct:
            continue
        
        if token.is_space:
            continue
        
        # keep only alphabetic words
        if not token.is_alpha:
            continue
        
        # lemma
        tokens.append(token.lemma_)
    
    return " ".join(tokens)

# %%
# Apply Pre-preocessing

# %%
df["processed_review"] = df["review"].apply(preprocess_text)

# %%
df.head()
# Out:
#                                              college  \
# 0                sns college of technology - [snsct]
# 1           bhagalpur college of engineering - [bce]
# 2  shree lr tiwari college of engineering - [slrtce]
# 3                                    iilm university
# 4                        galgotias university - [gu]
#
#                                               review  rating  label  \
# 0  the annual fee for the course is 1,25,000. now...     6.0      0
# 1  the hostel life and social life in this colleg...     9.7      0
# 2  i chose this course because i was interested i...     8.0      0
# 3  there is ignite fest in the university held on...    10.0      0
# 4  the civil department is very good in this coll...     6.2      0
#
#                                     processed_review
# 0  annual fee course force pay fee early total bo...
# 1  hostel life social life college enjoyable club...
# 2  choose course interested mechanical engineerin...
# 3  ignite f university hold campus availability j...
# 4  civil department good college faculty member g...

# %%
# save pre-processed dataset
df.to_csv("data/processed_reviews.csv", index=False)
